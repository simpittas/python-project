# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Dell\Desktop\jupyter notebook2\Flavors.csv")
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
group_by_frame = df.groupby("Base Flavor")

# %%
group_by_frame.mean("aggregate")
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
group_by_frame = df.groupby("Liked")

# %%
group_by_frame.mean("aggregate")
# Out:
#        Flavor Rating  Texture Rating  Total Rating
# Liked
# No               3.6        4.466667      8.066667
# Yes              8.1        7.033333     15.166667

# %%
group_by_frame = df.groupby("Liked")
group_by_frame.count()
# Out:
#        Flavor  Base Flavor  Flavor Rating  Texture Rating  Total Rating
# Liked
# No          3            3              3               3             3
# Yes         6            6              6               6             6

# %%
group_by_frame = df.groupby("Base Flavor")
group_by_frame.min()
# Out:
#                   Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate      Chocolate   Yes            8.2             7.0          15.2
# Vanilla      Cake Batter    No            2.3             3.4           5.7

# %%
group_by_frame = df.groupby("Base Flavor")
group_by_frame.max()
# Out:
#                  Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate    Rocky Road   Yes            8.8             7.6          16.6
# Vanilla         Vanilla   Yes           10.0             8.0          18.0

# %%
group_by_frame = df.groupby(["Base Flavor","Liked"])
group_by_frame.mean("aggregate")
# Out:
#                    Flavor Rating  Texture Rating  Total Rating
# Base Flavor Liked
# Chocolate   Yes              8.4        7.233333     15.700000
# Vanilla     No               3.6        4.466667      8.066667
#             Yes              7.8        6.833333     14.633333

# %%
df.groupby("Base Flavor").agg({"Flavor Rating":["mean","max","count","sum"]})
# Out:
#             Flavor Rating
#                      mean   max count   sum
# Base Flavor
# Chocolate             8.4   8.8     3  25.2
# Vanilla               5.7  10.0     6  34.2

# %%
df.groupby("Base Flavor").agg({"Texture Rating":["mean","max","count","sum"]})
# Out:
#             Texture Rating
#                       mean  max count   sum
# Base Flavor
# Chocolate         7.233333  7.6     3  21.7
# Vanilla           5.650000  8.0     6  33.9

# %%
df.groupby("Base Flavor").agg({"Total Rating":["mean","max","count","sum"]})
# Out:
#             Total Rating
#                     mean   max count   sum
# Base Flavor
# Chocolate          15.70  16.6     3  47.1
# Vanilla            11.35  18.0     6  68.1

# %%
df.groupby("Base Flavor").agg({"Flavor Rating":["mean","max","count","sum"],"Texture Rating":["mean","max","count","sum"],"Total Rating":["mean","max","count","sum"]})
# Out:
#             Flavor Rating                   Texture Rating                   \
#                      mean   max count   sum           mean  max count   sum
# Base Flavor
# Chocolate             8.4   8.8     3  25.2       7.233333  7.6     3  21.7
# Vanilla               5.7  10.0     6  34.2       5.650000  8.0     6  33.9
#
#             Total Rating
#                     mean   max count   sum
# Base Flavor
# Chocolate          15.70  16.6     3  47.1
# Vanilla            11.35  18.0     6  68.1

# %%
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
df.groupby("Base Flavor").describe()
# Out:
#             Flavor Rating                                             \
#                     count mean       std  min    25%  50%  75%   max
# Base Flavor
# Chocolate             3.0  8.4  0.346410  8.2  8.200  8.2  8.5   8.8
# Vanilla               6.0  5.7  2.710719  2.3  4.025  5.6  6.8  10.0
#
#             Texture Rating            ...             Total Rating         \
#                      count      mean  ...    75%  max        count   mean
# Base Flavor                           ...
# Chocolate              3.0  7.233333  ...  7.350  7.6          3.0  15.70
# Vanilla                6.0  5.650000  ...  6.375  8.0          6.0  11.35
#
#
#                   std   min     25%   50%     75%   max
# Base Flavor
# Chocolate    0.781025  15.2  15.250  15.3  15.950  16.6
# Vanilla      4.263684   5.7   9.025  11.1  13.175  18.0
#
# [2 rows x 24 columns]
