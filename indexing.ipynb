# %%
import pandas as pd

# %%
df1 = pd.read_excel(r"C:\Users\Dell\Desktop\python project\world_population_excel_workbook.xlsx")
df1
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df2 = df1.set_index("Country")
df2
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia         41128771
# Albania             138  ALB            Tirana    Europe          2842321
# Algeria              34  DZA           Algiers    Africa         44903225
# American Samoa      213  ASM         Pago Pago   Oceania            44273
# Andorra             203  AND  Andorra la Vella    Europe            79824
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania            11572
# Western Sahara      172  ESH         El AaiÃºn    Africa           575986
# Yemen                46  YEM             Sanaa      Asia         33696614
# Zambia               63  ZMB            Lusaka    Africa         20017675
# Zimbabwe             74  ZWE            Harare    Africa         16320537
#
# ...

# %%
df2.reset_index(inplace = True)
df2
# Out:
#                Country  Rank CCA3           Capital Continent  \
# 0          Afghanistan    36  AFG             Kabul      Asia
# 1              Albania   138  ALB            Tirana    Europe
# 2              Algeria    34  DZA           Algiers    Africa
# 3       American Samoa   213  ASM         Pago Pago   Oceania
# 4              Andorra   203  AND  Andorra la Vella    Europe
# ..                 ...   ...  ...               ...       ...
# 229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara   172  ESH         El AaiÃºn    Africa
# 231              Yemen    46  YEM             Sanaa      Asia
# 232             Zambia    63  ZMB            Lusaka    Africa
# 233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df2.loc[0:3,"Country":"Continent"]
# Out:
#           Country  Rank CCA3    Capital Continent
# 0     Afghanistan    36  AFG      Kabul      Asia
# 1         Albania   138  ALB     Tirana    Europe
# 2         Algeria    34  DZA    Algiers    Africa
# 3  American Samoa   213  ASM  Pago Pago   Oceania

# %%
df2.iloc[2,1]
# Out:
# 34

# %%
df2.iloc[0:4,0:5]
# Out:
#           Country  Rank CCA3    Capital Continent
# 0     Afghanistan    36  AFG      Kabul      Asia
# 1         Albania   138  ALB     Tirana    Europe
# 2         Algeria    34  DZA    Algiers    Africa
# 3  American Samoa   213  ASM  Pago Pago   Oceania

# %%
df3 = df1.set_index(["Continent","Country"])
df3
# Out:
#                              Rank CCA3           Capital  2022 Population  \
# Continent Country
# Asia      Afghanistan          36  AFG             Kabul         41128771
# Europe    Albania             138  ALB            Tirana          2842321
# Africa    Algeria              34  DZA           Algiers         44903225
# Oceania   American Samoa      213  ASM         Pago Pago            44273
# Europe    Andorra             203  AND  Andorra la Vella            79824
# ...                           ...  ...               ...              ...
# Oceania   Wallis and Futuna   226  WLF          Mata-Utu            11572
# Africa    Western Sahara      172  ESH         El AaiÃºn           575986
# Asia      Yemen                46  YEM             Sanaa         33696614
# Africa    Zambia               63  ZMB            Lusaka         20017675
#           Zimbabwe             74  ZWE            Harare         16320537
#
# ...

# %%
df3.loc["Asia","Afghanistan"]
# Out:
# Rank                                 36
# CCA3                                AFG
# Capital                           Kabul
# 2022 Population                41128771
# 2020 Population                38972230
# 2015 Population                33753499
# 2010 Population                28189672
# 2000 Population                19542982
# 1990 Population                10694796
# 1980 Population                12486631
# 1970 Population                10752971
# Area (kmÂ²)                      652230
# Density (per kmÂ²)              63.0587
# Growth Rate                      1.0257
# World Population Percentage        0.52
# Name: (Asia, Afghanistan), dtype: object

# %%
df2
# Out:
#                                   Rank CCA3              Capital  \
# Country
# Afghanistan                         36  AFG                Kabul
# Albania                            138  ALB               Tirana
# Algeria                             34  DZA              Algiers
# American Samoa                     213  ASM            Pago Pago
# Andorra                            203  AND     Andorra la Vella
# Angola                              42  AGO               Luanda
# Anguilla                           224  AIA           The Valley
# Antigua and Barbuda                201  ATG       Saint Johnâ€™s
# Argentina                           33  ARG         Buenos Aires
# Armenia                            140  ARM              Yerevan
# Aruba                              198  ABW           Oranjestad
# Australia                           55  AUS             Canberra
# Austria                             99  AUT               Vienna
# ...

# %%
pd.set_option("display.max.rows",234)

# %%
df2.sot_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5900\2606495504.py in ?()
# ----> 1 df2.sot_index()
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sot_index'
